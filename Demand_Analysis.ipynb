# %%
import pandas as pd

# %%
df = pd.read_csv('Historical_Product_Demand.csv')

# %%
df.head ()
# Out:
#    Product_Code Warehouse Product_Category       Date Order_Demand
# 0  Product_0993    Whse_J     Category_028  2012/7/27         100
# 1  Product_0979    Whse_J     Category_028  2012/1/19         500
# 2  Product_0979    Whse_J     Category_028   2012/2/3         500
# 3  Product_0979    Whse_J     Category_028   2012/2/9         500
# 4  Product_0979    Whse_J     Category_028   2012/3/2         500

# %%
print(f"Rows:          {len(df):,}")
# Out:
# Rows:          1,048,575

# %%
print(f"Columns:       {df.columns.tolist()}")
# Out:
# Columns:       ['Product_Code', 'Warehouse', 'Product_Category', 'Date', 'Order_Demand']

# %%
nan_dates = df[df['Date'].isna()]
print(f"NaN dates: {len(nan_dates)}")
# Out:
# NaN dates: 11239

# %%
print(f"Date range: {df['Date'].dropna().min().date()} to {df['Date'].dropna().max().date()}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/t9/gzpksxk17218812drw_sfgnr0000gn/T/ipykernel_54316/3073987215.py in <module>
# ----> 1 print(f"Date range: {df['Date'].dropna().min().date()} to {df['Date'].dropna().max().date()}")
#
# AttributeError: 'str' object has no attribute 'date'

# %%
print(df['Date'].dtype)
# Out:
# object

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
print(df['Date'].dtype)
# Out:
# datetime64[ns]

# %%
print(f"Date range: {df['Date'].dropna().min().date()} to {df['Date'].dropna().max().date()}")
# Out:
# Date range: 2011-01-08 to 2017-01-09

# %%
print(f"Products:      {df['Product_Code'].nunique()}")
print(f"Warehouses:    {df['Warehouse'].nunique()}")
print(f"Categories:    {df['Product_Category'].nunique()}")
# Out:
# Products:      2160
# Warehouses:    4
# Categories:    33

# %%
print(df.isnull().sum())
# Out:
# Product_Code            0
# Warehouse               0
# Product_Category        0
# Date                11239
# Order_Demand            0
# dtype: int64

# %%
df = df.dropna(subset=['Date'])

# %%
print(f"Rows:          {len(df):,}")
# Out:
# Rows:          1,037,336
